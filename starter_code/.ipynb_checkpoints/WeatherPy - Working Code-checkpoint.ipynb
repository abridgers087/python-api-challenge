# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
            
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        pprint(city_weather)
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        city_max_temp = (max_temp - 273.15)
        city_humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        city_clouds = f"{clouds}%"
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(city_weather["dt"]))
                
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp in Celsius": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anadyr
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 64.75, 'lon': 177.4833},
#  'dt': 1682184288,
#  'id': 2127202,
#  'main': {'feels_like': 258.71,
#           'humidity': 92,
#           'pressure': 1034,
#           'temp': 258.71,
#           'temp_max': 259.43,
#           'temp_min': 258.71},
#  'name': 'Anadyr',
#  'sys': {'country': 'RU',
#          'id': 47746,
#          'sunrise': 1682179770,
#          'sunset': 1682237234,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 400,
#  'weather': [{'description': 'fog', 'icon': '50d', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 0, 'speed': 0}}
# Processing Record 2 of Set 1 | port-aux-francais
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -49.35, 'lon': 70.2167},
#  'dt': 1682184322,
#  'id': 1546102,
#  'main': {'feels_like': 275.04,
#           'grnd_level': 1015,
#           'humidity': 93,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 280.86,
#           'temp_max': 280.86,
#           'temp_min': 280.86},
#  'name': 'Port-aux-Français',
#  'rain': {'1h': 0.19},
#  'sys': {'country': 'TF', 'sunrise': 1682129380, 'sunset': 1682166327},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 340, 'gust': 27.71, 'speed': 16.88}}
# Processing Record 3 of Set 1 | ushuaia
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1682184085,
#  'id': 3833367,
#  'main': {'feels_like': 282.4,
#           'humidity': 50,
#           'pressure': 988,
#           'temp': 283.96,
#           'temp_max': 283.96,
#           'temp_min': 283.96},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1682163392,
#          'sunset': 1682198795,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'gust': 15.43, 'speed': 8.75}}
# Processing Record 4 of Set 1 | invercargill
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': -46.4, 'lon': 168.35},
#  'dt': 1682184322,
#  'id': 2189529,
#  'main': {'feels_like': 284.19,
#           'humidity': 82,
#           'pressure': 1016,
#           'temp': 284.83,
#           'temp_max': 284.83,
#           'temp_min': 284.83},
#  'name': 'Invercargill',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1682191960,
#          'sunset': 1682229427,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 195, 'gust': 1.34, 'speed': 0.89}}
# Processing Record 5 of Set 1 | angaur state
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': 6.906, 'lon': 134.13},
#  'dt': 1682184792,
#  'id': 4038282,
#  'main': {'feels_like': 304.71,
#           'grnd_level': 1008,
#           'humidity': 75,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 301.24,
#           'temp_max': 301.24,
#           'temp_min': 301.24},
#  'name': 'Angaur State',
#  'sys': {'country': 'PW', 'sunrise': 1682196737, 'sunset': 1682241074},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 49, 'gust': 4.58, 'speed': 4.21}}
# Processing Record 6 of Set 1 | adrar
# {'base': 'stations',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': 20.5022, 'lon': -10.0711},
#  'dt': 1682184793,
#  'id': 2381972,
#  'main': {'feels_like': 301.58,
#           'grnd_level': 965,
#           'humidity': 14,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 303.52,
#           'temp_max': 303.52,
#           'temp_min': 303.52},
#  'name': 'Adrar',
#  'sys': {'country': 'MR', 'sunrise': 1682144198, 'sunset': 1682190043},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 347, 'gust': 4.7, 'speed': 5.47}}
# Processing Record 7 of Set 1 | aver-o-mar
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 41.4078, 'lon': -8.7812},
#  'dt': 1682184793,
#  'id': 2742578,
#  'main': {'feels_like': 290.52,
#           'humidity': 77,
#           'pressure': 1014,
#           'temp': 290.7,
#           'temp_max': 291.66,
#           'temp_min': 290.42},
#  'name': 'Aver-o-Mar',
#  'sys': {'country': 'PT',
#          'id': 6900,
#          'sunrise': 1682142318,
#          'sunset': 1682191304,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 5.66}}
# Processing Record 8 of Set 1 | aasiaat
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 68.7098, 'lon': -52.8699},
#  'dt': 1682184346,
#  'id': 3424901,
#  'main': {'feels_like': 272.84,
#           'grnd_level': 1034,
#           'humidity': 86,
#           'pressure': 1034,
#           'sea_level': 1034,
#           'temp': 272.84,
#           'temp_max': 272.84,
#           'temp_min': 272.84},
#  'name': 'Aasiaat',
#  'sys': {'country': 'GL', 'sunrise': 1682147062, 'sunset': 1682207720},
#  'timezone': -7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 139, 'gust': 1.6, 'speed': 1.24}}
# Processing Record 9 of Set 1 | silver city
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 32.7701, 'lon': -108.2803},
#  'dt': 1682184722,
#  'id': 5491487,
#  'main': {'feels_like': 291.84,
#           'humidity': 22,
#           'pressure': 1010,
#           'temp': 293.2,
#           'temp_max': 294.13,
#           'temp_min': 291.66},
#  'name': 'Silver City',
#  'sys': {'country': 'US',
#          'id': 2005069,
#          'sunrise': 1682166923,
#          'sunset': 1682214452,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 313, 'gust': 7.15, 'speed': 4.02}}
# Processing Record 10 of Set 1 | port elizabeth
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.918, 'lon': 25.5701},
#  'dt': 1682184330,
#  'id': 964420,
#  'main': {'feels_like': 289.32,
#           'humidity': 66,
#           'pressure': 1012,
#           'temp': 289.87,
#           'temp_max': 290.31,
#           'temp_min': 288.76},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 2072678,
#          'sunrise': 1682138704,
#          'sunset': 1682178431,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 290, 'speed': 2.57}}
# Processing Record 11 of Set 1 | andergrove
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -21.0833, 'lon': 149.1833},
#  'dt': 1682184794,
#  'id': 2177914,
#  'main': {'feels_like': 297.33,
#           'grnd_level': 1016,
#           'humidity': 79,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 296.84,
#           'temp_max': 296.84,
#           'temp_min': 296.84},
#  'name': 'Andergrove',
#  'rain': {'1h': 0.37},
#  'sys': {'country': 'AU',
#          'id': 254970,
#          'sunrise': 1682194630,
#          'sunset': 1682235956,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 135, 'gust': 13.43, 'speed': 10.7}}
# Processing Record 12 of Set 1 | stettler
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': 52.3168, 'lon': -112.7186},
#  'dt': 1682184795,
#  'id': 6156307,
#  'main': {'feels_like': 274.47,
#           'grnd_level': 926,
#           'humidity': 43,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 278.01,
#           'temp_max': 278.01,
#           'temp_min': 278.01},
#  'name': 'Stettler',
#  'sys': {'country': 'CA',
#          'id': 2016220,
#          'sunrise': 1682165903,
#          'sunset': 1682217602,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 161, 'gust': 5.03, 'speed': 4.67}}
# Processing Record 13 of Set 1 | crane
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 31.3974, 'lon': -102.3501},
#  'dt': 1682184352,
#  'id': 5519648,
#  'main': {'feels_like': 296.19,
#           'grnd_level': 924,
#           'humidity': 14,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 297.35,
#           'temp_max': 297.35,
#           'temp_min': 297.35},
#  'name': 'Crane',
#  'sys': {'country': 'US', 'sunrise': 1682165605, 'sunset': 1682212924},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 352, 'gust': 3.72, 'speed': 3.3}}
# Processing Record 14 of Set 1 | sachin
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 21.0833, 'lon': 72.8833},
#  'dt': 1682184795,
#  'id': 1257901,
#  'main': {'feels_like': 300.9,
#           'humidity': 42,
#           'pressure': 1006,
#           'temp': 301.09,
#           'temp_max': 301.09,
#           'temp_min': 301.09},
#  'name': 'Sachīn',
#  'sys': {'country': 'IN',
#          'id': 9071,
#          'sunrise': 1682124264,
#          'sunset': 1682170164,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 6000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 210, 'speed': 3.6}}
# Processing Record 15 of Set 1 | wailua homesteads
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 22.0669, 'lon': -159.378},
#  'dt': 1682184348,
#  'id': 7262802,
#  'main': {'feels_like': 295.23,
#           'humidity': 94,
#           'pressure': 1020,
#           'temp': 294.58,
#           'temp_max': 296.4,
#           'temp_min': 293.22},
#  'name': 'Wailua Homesteads',
#  'rain': {'1h': 1.14},
#  'sys': {'country': 'US',
#          'id': 2039329,
#          'sunrise': 1682179917,
#          'sunset': 1682225982,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 270, 'speed': 3.09}}
# Processing Record 16 of Set 1 | llazice
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': 42.5553, 'lon': 20.7633},
#  'dt': 1682184796,
#  'id': 788470,
#  'main': {'feels_like': 285.78,
#           'grnd_level': 941,
#           'humidity': 70,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 286.56,
#           'temp_max': 287.14,
#           'temp_min': 286.56},
#  'name': 'Llazice',
#  'sys': {'country': 'XK',
#          'id': 95,
#          'sunrise': 1682135120,
#          'sunset': 1682184322,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 72, 'gust': 3.88, 'speed': 2.71}}
# Processing Record 17 of Set 1 | waitangi
# {'base': 'stations',
#  'clouds': {'all': 81},
#  'cod': 200,
#  'coord': {'lat': -43.9535, 'lon': -176.5597},
#  'dt': 1682184192,
#  'id': 4032804,
#  'main': {'feels_like': 285.04,
#           'humidity': 96,
#           'pressure': 1015,
#           'temp': 285.27,
#           'temp_max': 285.27,
#           'temp_min': 285.27},
#  'name': 'Waitangi',
#  'sys': {'country': 'NZ',
#          'id': 2040615,
#          'sunrise': 1682274557,
#          'sunset': 1682312366,
#          'type': 2},
#  'timezone': 45900,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 86, 'gust': 2.24, 'speed': 0.89}}
# Processing Record 18 of Set 1 | puerto ayora
# {'base': 'stations',
#  'clouds': {'all': 63},
#  'cod': 200,
#  'coord': {'lat': -0.7393, 'lon': -90.3518},
#  'dt': 1682184324,
#  'id': 3652764,
#  'main': {'feels_like': 306.27,
#           'humidity': 85,
#           'pressure': 1010,
#           'temp': 301.23,
#           'temp_max': 303.13,
#           'temp_min': 301.23},
#  'name': 'Puerto Ayora',
#  'rain': {'1h': 0.1},
#  'sys': {'country': 'EC',
#          'id': 2005652,
#          'sunrise': 1682164620,
#          'sunset': 1682208151,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 168, 'gust': 8.94, 'speed': 6.26}}
# Processing Record 19 of Set 1 | fort-shevchenko
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 44.5086, 'lon': 50.263},
#  'dt': 1682184797,
#  'id': 609906,
#  'main': {'feels_like': 285.88,
#           'grnd_level': 1017,
#           'humidity': 65,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 286.77,
#           'temp_max': 286.77,
#           'temp_min': 286.77},
#  'name': 'Fort-Shevchenko',
#  'sys': {'country': 'KZ', 'sunrise': 1682127843, 'sunset': 1682177441},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 31, 'gust': 4.18, 'speed': 3.61}}
# Processing Record 20 of Set 1 | lebu
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -37.6167, 'lon': -73.65},
#  'dt': 1682184236,
#  'id': 3883457,
#  'main': {'feels_like': 287.66,
#           'grnd_level': 1014,
#           'humidity': 75,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 288.15,
#           'temp_max': 288.15,
#           'temp_min': 288.15},
#  'name': 'Lebu',
#  'sys': {'country': 'CL', 'sunrise': 1682162811, 'sunset': 1682201943},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 193, 'gust': 9.02, 'speed': 7.19}}
# Processing Record 21 of Set 1 | slave lake
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 55.2834, 'lon': -114.769},
#  'dt': 1682184798,
#  'id': 6149374,
#  'main': {'feels_like': 273.76,
#           'humidity': 48,
#           'pressure': 1020,
#           'temp': 278.14,
#           'temp_max': 278.14,
#           'temp_min': 278.14},
#  'name': 'Slave Lake',
#  'sys': {'country': 'CA',
#          'id': 1008,
#          'sunrise': 1682165902,
#          'sunset': 1682218588,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 140, 'gust': 9.26, 'speed': 6.69}}
# Processing Record 22 of Set 1 | afaahiti
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -17.75, 'lon': -149.2833},
#  'dt': 1682184342,
#  'id': 4034745,
#  'main': {'feels_like': 298.82,
#           'grnd_level': 993,
#           'humidity': 84,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 298.08,
#           'temp_max': 298.08,
#           'temp_min': 297.63},
#  'name': 'Afaahiti',
#  'rain': {'1h': 0.97},
#  'sys': {'country': 'PF',
#          'id': 7318,
#          'sunrise': 1682179668,
#          'sunset': 1682221386,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 252, 'gust': 7.84, 'speed': 7.26}}
# Processing Record 23 of Set 1 | grytviken
# {'base': 'stations',
#  'clouds': {'all': 54},
#  'cod': 200,
#  'coord': {'lat': -54.2811, 'lon': -36.5092},
#  'dt': 1682184323,
#  'id': 3426466,
#  'main': {'feels_like': 268.31,
#           'grnd_level': 979,
#           'humidity': 79,
#           'pressure': 984,
#           'sea_level': 984,
#           'temp': 274.73,
#           'temp_max': 274.73,
#           'temp_min': 274.73},
#  'name': 'Grytviken',
#  'snow': {'1h': 0.2},
#  'sys': {'country': 'GS', 'sunrise': 1682155674, 'sunset': 1682191256},
#  'timezone': -7200,
#  'visibility': 5428,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 232, 'gust': 15.15, 'speed': 9.69}}
# Processing Record 24 of Set 1 | adamstown
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -25.066, 'lon': -130.1015},
#  'dt': 1682184329,
#  'id': 4030723,
#  'main': {'feels_like': 299.08,
#           'grnd_level': 1002,
#           'humidity': 86,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 298.27,
#           'temp_max': 298.27,
#           'temp_min': 298.27},
#  'name': 'Adamstown',
#  'rain': {'1h': 0.97},
#  'sys': {'country': 'PN', 'sunrise': 1682175493, 'sunset': 1682216355},
#  'timezone': -28800,
#  'visibility': 9383,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 299, 'gust': 12.3, 'speed': 8.99}}
# Processing Record 25 of Set 1 | isafjordur
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 66.0755, 'lon': -23.124},
#  'dt': 1682184334,
#  'id': 3415667,
#  'main': {'feels_like': 272.81,
#           'grnd_level': 1032,
#           'humidity': 58,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': 275.63,
#           'temp_max': 275.63,
#           'temp_min': 275.63},
#  'name': 'Isafjordur',
#  'sys': {'country': 'IS', 'sunrise': 1682141126, 'sunset': 1682199379},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 104, 'gust': 2.69, 'speed': 2.78}}
# Processing Record 26 of Set 1 | olonkinbyen
# {'base': 'stations',
#  'clouds': {'all': 49},
#  'cod': 200,
#  'coord': {'lat': 70.9221, 'lon': -8.7187},
#  'dt': 1682184323,
#  'id': 7535941,
#  'main': {'feels_like': 263.9,
#           'grnd_level': 1028,
#           'humidity': 64,
#           'pressure': 1030,
#           'sea_level': 1030,
#           'temp': 270.07,
#           'temp_max': 270.07,
#           'temp_min': 270.07},
#  'name': 'Olonkinbyen',
#  'sys': {'country': 'SJ', 'sunrise': 1682135186, 'sunset': 1682198406},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 12, 'gust': 6.28, 'speed': 5.8}}
# Processing Record 27 of Set 1 | mili
# {'base': 'stations',
#  'clouds': {'all': 39},
#  'cod': 200,
#  'coord': {'lat': 6.0815, 'lon': 171.735},
#  'dt': 1682184799,
#  'id': 7306516,
#  'main': {'feels_like': 304.28,
#           'grnd_level': 1009,
#           'humidity': 81,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 300.7,
#           'temp_max': 300.7,
#           'temp_min': 300.7},
#  'name': 'Mili',
#  'rain': {'1h': 2.02},
#  'sys': {'country': 'MH', 'sunrise': 1682187758, 'sunset': 1682232005},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 68, 'gust': 8.1, 'speed': 7.28}}
# Processing Record 28 of Set 1 | columbia falls
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 48.3725, 'lon': -114.1815},
#  'dt': 1682184796,
#  'id': 5645859,
#  'main': {'feels_like': 276.02,
#           'humidity': 70,
#           'pressure': 1022,
#           'temp': 279.03,
#           'temp_max': 279.83,
#           'temp_min': 278.66},
#  'name': 'Columbia Falls',
#  'sys': {'country': 'US',
#          'id': 4253,
#          'sunrise': 1682166807,
#          'sunset': 1682217401,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 4.12}}
# Processing Record 29 of Set 1 | bonnyville
# {'base': 'stations',
#  'clouds': {'all': 29},
#  'cod': 200,
#  'coord': {'lat': 54.2668, 'lon': -110.735},
#  'dt': 1682184621,
#  'id': 5905616,
#  'main': {'feels_like': 273.56,
#           'grnd_level': 958,
#           'humidity': 40,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 277.04,
#           'temp_max': 277.04,
#           'temp_min': 277.04},
#  'name': 'Bonnyville',
#  'sys': {'country': 'CA',
#          'id': 870,
#          'sunrise': 1682165113,
#          'sunset': 1682217441,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 173, 'gust': 5.38, 'speed': 4.14}}
# Processing Record 30 of Set 1 | taiohae
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 31 of Set 1 | petropavlovsk-kamchatsky
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 53.0452, 'lon': 158.6483},
#  'dt': 1682184286,
#  'id': 2122104,
#  'main': {'feels_like': 268.65,
#           'humidity': 100,
#           'pressure': 986,
#           'temp': 273.48,
#           'temp_max': 273.48,
#           'temp_min': 273.03},
#  'name': 'Petropavlovsk-Kamchatskiy',
#  'snow': {'1h': 1.31},
#  'sys': {'country': 'RU',
#          'id': 8887,
#          'sunrise': 1682187029,
#          'sunset': 1682239015,
#          'type': 1},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'},
#              {'description': 'snow', 'icon': '13n', 'id': 601, 'main': 'Snow'}],
#  'wind': {'deg': 310, 'speed': 5}}
# Processing Record 32 of Set 1 | mirny
# {'base': 'stations',
#  'clouds': {'all': 7},
#  'cod': 200,
#  'coord': {'lat': 62.5353, 'lon': 113.9611},
#  'dt': 1682184382,
#  'id': 2019951,
#  'main': {'feels_like': 256.87,
#           'grnd_level': 991,
#           'humidity': 96,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': 256.87,
#           'temp_max': 256.87,
#           'temp_min': 256.87},
#  'name': 'Mirny',
#  'sys': {'country': 'RU', 'sunrise': 1682195689, 'sunset': 1682251802},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 242, 'gust': 0.75, 'speed': 0.75}}
# Processing Record 33 of Set 1 | cabedelo
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -6.9811, 'lon': -34.8339},
#  'dt': 1682184647,
#  'id': 3404558,
#  'main': {'feels_like': 310.81,
#           'grnd_level': 1008,
#           'humidity': 67,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 304.52,
#           'temp_max': 304.52,
#           'temp_min': 304.52},
#  'name': 'Cabedelo',
#  'sys': {'country': 'BR',
#          'id': 8391,
#          'sunrise': 1682151619,
#          'sunset': 1682194506,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 139, 'gust': 8.35, 'speed': 6.64}}
# Processing Record 34 of Set 1 | iqaluit
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 63.7506, 'lon': -68.5145},
#  'dt': 1682184349,
#  'id': 5983720,
#  'main': {'feels_like': 266.58,
#           'humidity': 93,
#           'pressure': 1021,
#           'temp': 272.98,
#           'temp_max': 273,
#           'temp_min': 272.98},
#  'name': 'Iqaluit',
#  'sys': {'country': 'CA',
#          'id': 47658,
#          'sunrise': 1682152810,
#          'sunset': 1682209480,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 140, 'speed': 8.05}}
# Processing Record 35 of Set 1 | betio village
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 1.358, 'lon': 172.9211},
#  'dt': 1682184802,
#  'id': 2110248,
#  'main': {'feels_like': 305.14,
#           'grnd_level': 1009,
#           'humidity': 79,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 301.17,
#           'temp_max': 301.17,
#           'temp_min': 301.17},
#  'name': 'Betio Village',
#  'sys': {'country': 'KI',
#          'id': 7300,
#          'sunrise': 1682187722,
#          'sunset': 1682231472,
#          'type': 1},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 104, 'gust': 6.23, 'speed': 5.42}}
# Processing Record 36 of Set 1 | west island
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -12.1568, 'lon': 96.8225},
#  'dt': 1682184338,
#  'id': 7304591,
#  'main': {'feels_like': 305.69,
#           'humidity': 83,
#           'pressure': 1011,
#           'temp': 301.14,
#           'temp_max': 301.14,
#           'temp_min': 301.14},
#  'name': 'West Island',
#  'sys': {'country': 'CC',
#          'id': 9570,
#          'sunrise': 1682120291,
#          'sunset': 1682162648,
#          'type': 1},
#  'timezone': 23400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 5.66}}
# Processing Record 37 of Set 1 | atbasar
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 51.8, 'lon': 68.3333},
#  'dt': 1682184803,
#  'id': 1526038,
#  'main': {'feels_like': 280.96,
#           'grnd_level': 985,
#           'humidity': 62,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 282.96,
#           'temp_max': 282.96,
#           'temp_min': 282.96},
#  'name': 'Atbasar',
#  'sys': {'country': 'KZ', 'sunrise': 1682122591, 'sunset': 1682174020},
#  'timezone': 21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 168, 'gust': 8.28, 'speed': 3.92}}
# Processing Record 38 of Set 1 | yigo village
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 13.5361, 'lon': 144.8886},
#  'dt': 1682184803,
#  'id': 4038794,
#  'main': {'feels_like': 299.39,
#           'humidity': 87,
#           'pressure': 1011,
#           'temp': 299.39,
#           'temp_max': 299.77,
#           'temp_min': 299.12},
#  'name': 'Yigo Village',
#  'sys': {'country': 'GU',
#          'id': 7856,
#          'sunrise': 1682193792,
#          'sunset': 1682238856,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 5.66}}
# Processing Record 39 of Set 1 | rongelap
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 11.1635, 'lon': 166.8941},
#  'dt': 1682184382,
#  'id': 7306520,
#  'main': {'feels_like': 302.95,
#           'grnd_level': 1011,
#           'humidity': 79,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 300.22,
#           'temp_max': 300.22,
#           'temp_min': 300.22},
#  'name': 'Rongelap',
#  'rain': {'1h': 0.19},
#  'sys': {'country': 'MH', 'sunrise': 1682188644, 'sunset': 1682233442},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 71, 'gust': 9.24, 'speed': 8.74}}
# Processing Record 40 of Set 1 | vikhorevka
# {'base': 'stations',
#  'clouds': {'all': 84},
#  'cod': 200,
#  'coord': {'lat': 56.1201, 'lon': 101.1636},
#  'dt': 1682184804,
#  'id': 2013399,
#  'main': {'feels_like': 268.87,
#           'grnd_level': 985,
#           'humidity': 98,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': 270.92,
#           'temp_max': 270.92,
#           'temp_min': 270.51},
#  'name': 'Vikhorevka',
#  'sys': {'country': 'RU',
#          'id': 8892,
#          'sunrise': 1682200266,
#          'sunset': 1682253367,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 289, 'gust': 2.34, 'speed': 1.49}}
# Processing Record 41 of Set 1 | coquimbo
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -29.9533, 'lon': -71.3436},
#  'dt': 1682184242,
#  'id': 3893629,
#  'main': {'feels_like': 288.78,
#           'humidity': 82,
#           'pressure': 1017,
#           'temp': 289,
#           'temp_max': 289,
#           'temp_min': 289},
#  'name': 'Coquimbo',
#  'sys': {'country': 'CL',
#          'id': 8514,
#          'sunrise': 1682161699,
#          'sunset': 1682201949,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 4.63}}
# Processing Record 42 of Set 1 | tangalle
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 6.024, 'lon': 80.7911},
#  'dt': 1682184804,
#  'id': 1227037,
#  'main': {'feels_like': 299.33,
#           'grnd_level': 1005,
#           'humidity': 88,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 298.45,
#           'temp_max': 298.45,
#           'temp_min': 298.45},
#  'name': 'Tangalle',
#  'sys': {'country': 'LK', 'sunrise': 1682123202, 'sunset': 1682167430},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 27, 'gust': 3.04, 'speed': 2.43}}
# Processing Record 43 of Set 1 | cafayate
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -26.073, 'lon': -65.9761},
#  'dt': 1682184805,
#  'id': 3863503,
#  'main': {'feels_like': 290.51,
#           'grnd_level': 843,
#           'humidity': 67,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 290.93,
#           'temp_max': 290.93,
#           'temp_min': 290.93},
#  'name': 'Cafayate',
#  'sys': {'country': 'AR', 'sunrise': 1682160160, 'sunset': 1682200912},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 64, 'gust': 3.91, 'speed': 3.87}}
# Processing Record 44 of Set 1 | kembe
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 4.6228, 'lon': 21.8865},
#  'dt': 1682184805,
#  'id': 238373,
#  'main': {'feels_like': 297.39,
#           'grnd_level': 953,
#           'humidity': 82,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 296.83,
#           'temp_max': 296.83,
#           'temp_min': 296.83},
#  'name': 'Kembé',
#  'sys': {'country': 'CF', 'sunrise': 1682137409, 'sunset': 1682181494},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 222, 'gust': 2.62, 'speed': 1.42}}
# Processing Record 45 of Set 1 | kodiak
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.4072},
#  'dt': 1682184238,
#  'id': 5866583,
#  'main': {'feels_like': 278.06,
#           'humidity': 36,
#           'pressure': 1014,
#           'temp': 280.88,
#           'temp_max': 280.88,
#           'temp_min': 280.88},
#  'name': 'Saint Paul Harbor',
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1682174434,
#          'sunset': 1682228119,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 290, 'speed': 4.63}}
# Processing Record 46 of Set 1 | east ballina
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': -28.8667, 'lon': 153.5833},
#  'dt': 1682184645,
#  'id': 2167943,
#  'main': {'feels_like': 287.78,
#           'grnd_level': 1024,
#           'humidity': 61,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 288.59,
#           'temp_max': 288.59,
#           'temp_min': 288.59},
#  'name': 'East Ballina',
#  'sys': {'country': 'AU',
#          'id': 2032240,
#          'sunrise': 1682194058,
#          'sunset': 1682234417,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 153, 'gust': 9.63, 'speed': 7.2}}
# Processing Record 47 of Set 1 | bilibino
# {'base': 'stations',
#  'clouds': {'all': 42},
#  'cod': 200,
#  'coord': {'lat': 68.0546, 'lon': 166.4372},
#  'dt': 1682184158,
#  'id': 2126682,
#  'main': {'feels_like': 258.54,
#           'grnd_level': 994,
#           'humidity': 73,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': 262.64,
#           'temp_max': 262.64,
#           'temp_min': 262.64},
#  'name': 'Bilibino',
#  'sys': {'country': 'RU', 'sunrise': 1682181050, 'sunset': 1682241256},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 55, 'gust': 1.68, 'speed': 1.95}}
# Processing Record 48 of Set 1 | albany
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1682184123,
#  'id': 5106841,
#  'main': {'feels_like': 289.31,
#           'humidity': 63,
#           'pressure': 1011,
#           'temp': 289.93,
#           'temp_max': 291.25,
#           'temp_min': 288.29},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1682157827,
#          'sunset': 1682207080,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 105, 'gust': 3.13, 'speed': 1.79}}
# Processing Record 49 of Set 1 | talnakh
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 69.4865, 'lon': 88.3972},
#  'dt': 1682184342,
#  'id': 1490256,
#  'main': {'feels_like': 269.23,
#           'grnd_level': 1012,
#           'humidity': 94,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': 274.38,
#           'temp_max': 274.38,
#           'temp_min': 274.38},
#  'name': 'Talnakh',
#  'snow': {'1h': 0.17},
#  'sys': {'country': 'RU',
#          'id': 49144,
#          'sunrise': 1682198954,
#          'sunset': 1682260806,
#          'type': 2},
#  'timezone': 25200,
#  'visibility': 727,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 135, 'gust': 13.01, 'speed': 6.07}}
# Processing Record 50 of Set 1 | pitimbu
# {'base': 'stations',
#  'clouds': {'all': 27},
#  'cod': 200,
#  'coord': {'lat': -7.4706, 'lon': -34.8086},
#  'dt': 1682184807,
#  'id': 3391889,
#  'main': {'feels_like': 311.48,
#           'grnd_level': 1007,
#           'humidity': 70,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 304.48,
#           'temp_max': 304.48,
#           'temp_min': 304.48},
#  'name': 'Pitimbu',
#  'sys': {'country': 'BR',
#          'id': 8391,
#          'sunrise': 1682151639,
#          'sunset': 1682194475,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 142, 'gust': 7.17, 'speed': 5.92}}
# Processing Record 0 of Set 2 | avarua
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -21.2078, 'lon': -159.775},
#  'dt': 1682184674,
#  'id': 4035715,
#  'main': {'feels_like': 296.71,
#           'humidity': 83,
#           'pressure': 1011,
#           'temp': 296.18,
#           'temp_max': 296.18,
#           'temp_min': 296.18},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'sunrise': 1682182385,
#          'sunset': 1682223705,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 2.06}}
# Processing Record 1 of Set 2 | udachny
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 66.4167, 'lon': 112.4},
#  'dt': 1682184333,
#  'id': 2014624,
#  'main': {'feels_like': 259.9,
#           'grnd_level': 990,
#           'humidity': 97,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': 264.22,
#           'temp_max': 264.22,
#           'temp_min': 264.22},
#  'name': 'Udachny',
#  'sys': {'country': 'RU', 'sunrise': 1682194715, 'sunset': 1682253525},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 238, 'gust': 2.36, 'speed': 2.25}}
# Processing Record 2 of Set 2 | codrington
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': -38.2667, 'lon': 141.9667},
#  'dt': 1682184568,
#  'id': 2171099,
#  'main': {'feels_like': 287.14,
#           'grnd_level': 1030,
#           'humidity': 87,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': 287.39,
#           'temp_max': 287.39,
#           'temp_min': 287.39},
#  'name': 'Codrington',
#  'sys': {'country': 'AU', 'sunrise': 1682197538, 'sunset': 1682236512},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 6, 'gust': 1.52, 'speed': 1.16}}
# Processing Record 3 of Set 2 | guimar
# {'base': 'stations',
#  'clouds': {'all': 81},
#  'cod': 200,
#  'coord': {'lat': 28.3039, 'lon': -16.4325},
#  'dt': 1682184808,
#  'id': 2516852,
#  'main': {'feels_like': 291.28,
#           'grnd_level': 953,
#           'humidity': 82,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 291.27,
#           'temp_max': 292.65,
#           'temp_min': 290.12},
#  'name': 'Güimar',
#  'sys': {'country': 'ES',
#          'id': 2002772,
#          'sunrise': 1682145221,
#          'sunset': 1682192073,
#          'type': 2},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'gust': 1.4, 'speed': 0.61}}
# Processing Record 4 of Set 2 | bridgewater
# {'base': 'stations',
#  'clouds': {'all': 87},
#  'cod': 200,
#  'coord': {'lat': 44.3835, 'lon': -64.5155},
#  'dt': 1682184809,
#  'id': 5908723,
#  'main': {'feels_like': 283.94,
#           'humidity': 41,
#           'pressure': 1022,
#           'temp': 285.57,
#           'temp_max': 286.54,
#           'temp_min': 281.94},
#  'name': 'Bridgewater',
#  'sys': {'country': 'CA',
#          'id': 2041151,
#          'sunrise': 1682155372,
#          'sunset': 1682204998,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 3.09}}
# Processing Record 5 of Set 2 | remire-montjoly
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 4.9167, 'lon': -52.2667},
#  'dt': 1682184337,
#  'id': 3380892,
#  'main': {'feels_like': 298.08,
#           'humidity': 94,
#           'pressure': 1009,
#           'temp': 297.17,
#           'temp_max': 297.17,
#           'temp_min': 297.17},
#  'name': 'Rémire-Montjoly',
#  'rain': {'1h': 1.73},
#  'sys': {'country': 'GF',
#          'id': 8669,
#          'sunrise': 1682155187,
#          'sunset': 1682199305,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 4800,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 80, 'speed': 2.06}}
# Processing Record 6 of Set 2 | les avirons
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2418, 'lon': 55.3394},
#  'dt': 1682184810,
#  'id': 935608,
#  'main': {'feels_like': 297.22,
#           'humidity': 78,
#           'pressure': 1013,
#           'temp': 296.77,
#           'temp_max': 297.2,
#           'temp_min': 295.58},
#  'name': 'Les Avirons',
#  'sys': {'country': 'RE',
#          'id': 2127,
#          'sunrise': 1682130746,
#          'sunset': 1682172102,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 2.06}}
# Processing Record 7 of Set 2 | lihue
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 21.9789, 'lon': -159.3672},
#  'dt': 1682184344,
#  'id': 5850248,
#  'main': {'feels_like': 295.49,
#           'humidity': 92,
#           'pressure': 1020,
#           'temp': 294.86,
#           'temp_max': 296.73,
#           'temp_min': 293.56},
#  'name': 'Lihue',
#  'rain': {'1h': 0.15},
#  'sys': {'country': 'US',
#          'id': 7873,
#          'sunrise': 1682179920,
#          'sunset': 1682225974,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 270, 'speed': 3.09}}
# Processing Record 8 of Set 2 | pimentel
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -6.8367, 'lon': -79.9342},
#  'dt': 1682184593,
#  'id': 3693584,
#  'main': {'feels_like': 307.12,
#           'humidity': 55,
#           'pressure': 1010,
#           'temp': 304.31,
#           'temp_max': 304.31,
#           'temp_min': 304.31},
#  'name': 'Pimentel',
#  'sys': {'country': 'PE',
#          'id': 8680,
#          'sunrise': 1682162436,
#          'sunset': 1682205335,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 2.06}}
# Processing Record 9 of Set 2 | klyuchi
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 52.2667, 'lon': 79.1667},
#  'dt': 1682184342,
#  'id': 1503153,
#  'main': {'feels_like': 271.35,
#           'grnd_level': 1012,
#           'humidity': 77,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 274.87,
#           'temp_max': 274.87,
#           'temp_min': 274.87},
#  'name': 'Klyuchi',
#  'sys': {'country': 'RU', 'sunrise': 1682206199, 'sunset': 1682257991},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 153, 'gust': 5.24, 'speed': 3.46}}
# Processing Record 10 of Set 2 | cockburn town
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 21.4612, 'lon': -71.1419},
#  'dt': 1682184811,
#  'id': 3576994,
#  'main': {'feels_like': 298.55,
#           'grnd_level': 1010,
#           'humidity': 69,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 298.19,
#           'temp_max': 298.19,
#           'temp_min': 298.19},
#  'name': 'Cockburn Town',
#  'sys': {'country': 'TC', 'sunrise': 1682158789, 'sunset': 1682204762},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 331, 'gust': 3.64, 'speed': 3.63}}
# Processing Record 11 of Set 2 | ancud
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -41.8697, 'lon': -73.8203},
#  'dt': 1682184711,
#  'id': 3899695,
#  'main': {'feels_like': 285.99,
#           'grnd_level': 1014,
#           'humidity': 66,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 286.84,
#           'temp_max': 286.84,
#           'temp_min': 286.84},
#  'name': 'Ancud',
#  'sys': {'country': 'CL', 'sunrise': 1682163213, 'sunset': 1682201623},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 253, 'gust': 2.11, 'speed': 2.21}}
# Processing Record 12 of Set 2 | gaalkacyo
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 6.7697, 'lon': 47.4308},
#  'dt': 1682184811,
#  'id': 59611,
#  'main': {'feels_like': 303.7,
#           'grnd_level': 975,
#           'humidity': 62,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 301.69,
#           'temp_max': 301.69,
#           'temp_min': 301.69},
#  'name': 'Gaalkacyo',
#  'sys': {'country': 'SO', 'sunrise': 1682131168, 'sunset': 1682175476},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 109, 'gust': 11.72, 'speed': 9.75}}
# Processing Record 13 of Set 2 | aksu
# {'base': 'stations',
#  'clouds': {'all': 13},
#  'cod': 200,
#  'coord': {'lat': 41.1231, 'lon': 80.2644},
#  'dt': 1682184812,
#  'id': 1529660,
#  'main': {'feels_like': 282.67,
#           'grnd_level': 893,
#           'humidity': 46,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 284.3,
#           'temp_max': 284.3,
#           'temp_min': 284.3},
#  'name': 'Aksu',
#  'sys': {'country': 'CN', 'sunrise': 1682207309, 'sunset': 1682256354},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 44, 'gust': 6.33, 'speed': 2.9}}
# Processing Record 14 of Set 2 | bredasdorp
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.5322, 'lon': 20.0403},
#  'dt': 1682184752,
#  'id': 1015776,
#  'main': {'feels_like': 286.97,
#           'grnd_level': 1001,
#           'humidity': 72,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 287.59,
#           'temp_max': 287.59,
#           'temp_min': 287.59},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA', 'sunrise': 1682140077, 'sunset': 1682179713},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 331, 'gust': 5.77, 'speed': 2.88}}
# Processing Record 15 of Set 2 | puerto natales
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
# ...
#  'main': {'feels_like': 304.7,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 302,
#           'temp_max': 302,
#           'temp_min': 302},
#  'name': 'Olinda',
#  'sys': {'country': 'BR',
#          'id': 8426,
#          'sunrise': 1682151678,
#          'sunset': 1682194458,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 4.12}}
# Processing Record 30 of Set 12 | kargopol'
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 61.5071, 'lon': 38.9456},
#  'dt': 1682184956,
#  'id': 552465,
#  'main': {'feels_like': 275.49,
#           'grnd_level': 993,
#           'humidity': 97,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 277.71,
#           'temp_max': 277.71,
#           'temp_min': 277.71},
#  'name': "Kargopol'",
#  'sys': {'country': 'RU', 'sunrise': 1682127728, 'sunset': 1682182988},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 261, 'gust': 9.49, 'speed': 2.54}}
# Processing Record 31 of Set 12 | chernomorskoye
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': 45.5039, 'lon': 32.6997},
#  'dt': 1682184957,
#  'id': 710687,
#  'main': {'feels_like': 282.91,
#           'grnd_level': 1014,
#           'humidity': 82,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 283.66,
#           'temp_max': 283.66,
#           'temp_min': 283.66},
#  'name': 'Chernomorskoye',
#  'sys': {'country': 'UA', 'sunrise': 1682131943, 'sunset': 1682181770},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 309, 'gust': 5.38, 'speed': 4.04}}
# Processing Record 32 of Set 12 | gamba
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -2.65, 'lon': 10},
#  'dt': 1682184957,
#  'id': 2400547,
#  'main': {'feels_like': 299.18,
#           'grnd_level': 1005,
#           'humidity': 83,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 299.18,
#           'temp_max': 299.18,
#           'temp_min': 299.18},
#  'name': 'Gamba',
#  'sys': {'country': 'GA', 'sunrise': 1682140636, 'sunset': 1682183972},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'gust': 5.16, 'speed': 3.07}}
# Processing Record 33 of Set 12 | nuku'alofa
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -21.1333, 'lon': -175.2},
#  'dt': 1682184957,
#  'id': 4032402,
#  'main': {'feels_like': 297.01,
#           'humidity': 88,
#           'pressure': 1013,
#           'temp': 296.34,
#           'temp_max': 296.34,
#           'temp_min': 296.34},
#  'name': "Nuku'alofa",
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1682272505,
#          'sunset': 1682313766,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'speed': 3.6}}
# Processing Record 34 of Set 12 | murun-kuren
# {'base': 'stations',
#  'clouds': {'all': 39},
#  'cod': 200,
#  'coord': {'lat': 49.6342, 'lon': 100.1625},
#  'dt': 1682184957,
#  'id': 2029945,
#  'main': {'feels_like': 271.92,
#           'grnd_level': 880,
#           'humidity': 24,
#           'pressure': 1030,
#           'sea_level': 1030,
#           'temp': 271.92,
#           'temp_max': 271.92,
#           'temp_min': 271.92},
#  'name': 'Mörön',
#  'sys': {'country': 'MN', 'sunrise': 1682201551, 'sunset': 1682252562},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 41, 'gust': 1.42, 'speed': 1.03}}
# Processing Record 35 of Set 12 | mpulungu
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': -8.7623, 'lon': 31.1141},
#  'dt': 1682184856,
#  'id': 175961,
#  'main': {'feels_like': 296.79,
#           'grnd_level': 924,
#           'humidity': 85,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 296.21,
#           'temp_max': 296.21,
#           'temp_min': 296.21},
#  'name': 'Mpulungu',
#  'rain': {'1h': 0.32},
#  'sys': {'country': 'ZM', 'sunrise': 1682135884, 'sunset': 1682178590},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 142, 'gust': 5.28, 'speed': 2.61}}
# Processing Record 36 of Set 12 | luganville
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -15.5333, 'lon': 167.1667},
#  'dt': 1682184958,
#  'id': 2136150,
#  'main': {'feels_like': 299.95,
#           'grnd_level': 1011,
#           'humidity': 86,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 299.06,
#           'temp_max': 299.06,
#           'temp_min': 299.06},
#  'name': 'Luganville',
#  'sys': {'country': 'VU', 'sunrise': 1682189998, 'sunset': 1682231958},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 149, 'gust': 4.59, 'speed': 3.07}}
# Processing Record 37 of Set 12 | micco
# {'base': 'stations',
#  'clouds': {'all': 34},
#  'cod': 200,
#  'coord': {'lat': 27.8806, 'lon': -80.5003},
#  'dt': 1682184958,
#  'id': 4164253,
#  'main': {'feels_like': 304.06,
#           'humidity': 65,
#           'pressure': 1011,
#           'temp': 301.65,
#           'temp_max': 303.2,
#           'temp_min': 299.26},
#  'name': 'Micco',
#  'sys': {'country': 'US',
#          'id': 2008109,
#          'sunrise': 1682160617,
#          'sunset': 1682207426,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 115, 'gust': 4.02, 'speed': 4.02}}
# Processing Record 38 of Set 12 | hihifo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 39 of Set 12 | altoona
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 40.5187, 'lon': -78.3947},
#  'dt': 1682184958,
#  'id': 5178195,
#  'main': {'feels_like': 285.92,
#           'humidity': 85,
#           'pressure': 1007,
#           'temp': 286.33,
#           'temp_max': 288.21,
#           'temp_min': 284.94},
#  'name': 'Altoona',
#  'rain': {'1h': 1.64},
#  'sys': {'country': 'US',
#          'id': 2006541,
#          'sunrise': 1682159094,
#          'sunset': 1682207938,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 245, 'gust': 4.02, 'speed': 1.34}}
# Processing Record 40 of Set 12 | tutoia
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -2.7619, 'lon': -42.2744},
#  'dt': 1682184727,
#  'id': 3385899,
#  'main': {'feels_like': 307.02,
#           'grnd_level': 1006,
#           'humidity': 60,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 303.68,
#           'temp_max': 303.68,
#           'temp_min': 303.68},
#  'name': 'Tutóia',
#  'sys': {'country': 'BR', 'sunrise': 1682153187, 'sunset': 1682196510},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 54, 'gust': 4.77, 'speed': 4.5}}
# Processing Record 41 of Set 12 | bentiu
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 9.2333, 'lon': 29.8333},
#  'dt': 1682184959,
#  'id': 377472,
#  'main': {'feels_like': 305.94,
#           'grnd_level': 959,
#           'humidity': 26,
#           'pressure': 1002,
#           'sea_level': 1002,
#           'temp': 307.26,
#           'temp_max': 307.26,
#           'temp_min': 307.26},
#  'name': 'Bentiu',
#  'sys': {'country': 'SS', 'sunrise': 1682135260, 'sunset': 1682179829},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 176, 'gust': 2.35, 'speed': 2.07}}
# Processing Record 42 of Set 12 | jugsalai
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 22.7667, 'lon': 86.1833},
#  'dt': 1682184959,
#  'id': 1268799,
#  'main': {'feels_like': 301.5,
#           'grnd_level': 989,
#           'humidity': 35,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 302.31,
#           'temp_max': 302.31,
#           'temp_min': 302.31},
#  'name': 'Jugsālai',
#  'sys': {'country': 'IN', 'sunrise': 1682120971, 'sunset': 1682167074},
#  'timezone': 19800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 254, 'gust': 6.22, 'speed': 3.12}}
# Processing Record 43 of Set 12 | pisco
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': -13.7, 'lon': -76.2167},
#  'dt': 1682184959,
#  'id': 3932145,
#  'main': {'feels_like': 302.32,
#           'humidity': 57,
#           'pressure': 1011,
#           'temp': 301.18,
#           'temp_max': 301.18,
#           'temp_min': 301.18},
#  'name': 'Pisco',
#  'sys': {'country': 'PE',
#          'id': 8691,
#          'sunrise': 1682161906,
#          'sunset': 1682204080,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 9000,
#  'weather': [{'description': 'smoke',
#               'icon': '50d',
#               'id': 711,
#               'main': 'Smoke'}],
#  'wind': {'deg': 220, 'speed': 9.26}}
# Processing Record 44 of Set 12 | cooma
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -36.2333, 'lon': 149.1333},
#  'dt': 1682184959,
#  'id': 2170577,
#  'main': {'feels_like': 280.12,
#           'grnd_level': 938,
#           'humidity': 94,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': 280.12,
#           'temp_max': 280.12,
#           'temp_min': 280.12},
#  'name': 'Cooma',
#  'sys': {'country': 'AU', 'sunrise': 1682195654, 'sunset': 1682234956},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 214, 'gust': 1.15, 'speed': 1.15}}
# Processing Record 45 of Set 12 | obo
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 5.3998, 'lon': 26.4869},
#  'dt': 1682184960,
#  'id': 236950,
#  'main': {'feels_like': 299.06,
#           'grnd_level': 936,
#           'humidity': 67,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 298.7,
#           'temp_max': 298.7,
#           'temp_min': 298.7},
#  'name': 'Obo',
#  'sys': {'country': 'CF', 'sunrise': 1682136265, 'sunset': 1682180430},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'gust': 8.29, 'speed': 2.73}}
# Processing Record 46 of Set 12 | maracaibo
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 10.6317, 'lon': -71.6406},
#  'dt': 1682184960,
#  'id': 3633009,
#  'main': {'feels_like': 305.95,
#           'grnd_level': 1006,
#           'humidity': 62,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 302.93,
#           'temp_max': 302.93,
#           'temp_min': 302.93},
#  'name': 'Maracaibo',
#  'sys': {'country': 'VE', 'sunrise': 1682159531, 'sunset': 1682204259},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 343, 'gust': 1.86, 'speed': 0.43}}
# Processing Record 47 of Set 12 | alaghsas
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 17.0187, 'lon': 8.0168},
#  'dt': 1682184590,
#  'id': 2447938,
#  'main': {'feels_like': 308.99,
#           'humidity': 9,
#           'pressure': 1003,
#           'temp': 312.09,
#           'temp_max': 312.09,
#           'temp_min': 312.09},
#  'name': 'Alaghsas',
#  'sys': {'country': 'NE',
#          'id': 1190,
#          'sunrise': 1682140064,
#          'sunset': 1682185496,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 4600,
#  'weather': [{'description': 'dust', 'icon': '50d', 'id': 761, 'main': 'Dust'}],
#  'wind': {'deg': 300, 'speed': 6.69}}
# Processing Record 48 of Set 12 | valdivia
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': -39.8142, 'lon': -73.2459},
#  'dt': 1682184960,
#  'id': 3868707,
#  'main': {'feels_like': 285.73,
#           'grnd_level': 1016,
#           'humidity': 41,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 287.2,
#           'temp_max': 287.2,
#           'temp_min': 287.2},
#  'name': 'Valdivia',
#  'sys': {'country': 'CL',
#          'id': 8526,
#          'sunrise': 1682162895,
#          'sunset': 1682201666,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 173, 'gust': 2, 'speed': 1}}
# Processing Record 49 of Set 12 | necochea
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': -38.5473, 'lon': -58.7368},
#  'dt': 1682184961,
#  'id': 3430443,
#  'main': {'feels_like': 288.02,
#           'grnd_level': 1021,
#           'humidity': 62,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': 288.78,
#           'temp_max': 288.78,
#           'temp_min': 288.78},
#  'name': 'Necochea',
#  'sys': {'country': 'AR', 'sunrise': 1682159305, 'sunset': 1682198292},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 133, 'gust': 4.18, 'speed': 4.6}}
# Processing Record 0 of Set 13 | hinton
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 53.4001, 'lon': -117.5857},
#  'dt': 1682184961,
#  'id': 5975503,
#  'main': {'feels_like': 279,
#           'grnd_level': 899,
#           'humidity': 57,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 279.75,
#           'temp_max': 279.75,
#           'temp_min': 279.75},
#  'name': 'Hinton',
#  'sys': {'country': 'CA', 'sunrise': 1682166898, 'sunset': 1682218943},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 184, 'gust': 2.63, 'speed': 1.44}}
# Processing Record 1 of Set 13 | valparaiso
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -33.0393, 'lon': -71.6273},
#  'dt': 1682184961,
#  'id': 3868626,
#  'main': {'feels_like': 290.98,
#           'humidity': 72,
#           'pressure': 1016,
#           'temp': 291.24,
#           'temp_max': 291.28,
#           'temp_min': 289.95},
#  'name': 'Valparaíso',
#  'sys': {'country': 'CL',
#          'id': 8498,
#          'sunrise': 1682161980,
#          'sunset': 1682201804,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 3500,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 310, 'speed': 5.66}}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City                   577
# Lat                    577
# Lng                    577
# Max Temp in Celsius    577
# Humidity               577
# Cloudiness             577
# Wind Speed             577
# Country                577
# Date                   577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City     Lat       Lng  Max Temp in Celsius  Humidity  \
# 0             anadyr  64.750  177.4833               -13.72        92
# 1  port-aux-francais -49.350   70.2167                 7.71        93
# 2            ushuaia -54.800  -68.3000                10.81        50
# 3       invercargill -46.400  168.3500                11.68        82
# 4       angaur state   6.906  134.1300                28.09        75
#
#   Cloudiness  Wind Speed Country                 Date
# 0        40%        0.00      RU  2023-04-22 12:24:48
# 1       100%       16.88      TF  2023-04-22 12:25:22
# 2        75%        8.75      AR  2023-04-22 12:21:25
# 3        93%        0.89      NZ  2023-04-22 12:25:22
# 4        95%        4.21      PW  2023-04-22 12:33:12

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City     Lat       Lng  Max Temp in Celsius  Humidity  \
# City_ID
# 0                   anadyr  64.750  177.4833               -13.72        92
# 1        port-aux-francais -49.350   70.2167                 7.71        93
# 2                  ushuaia -54.800  -68.3000                10.81        50
# 3             invercargill -46.400  168.3500                11.68        82
# 4             angaur state   6.906  134.1300                28.09        75
#
#         Cloudiness  Wind Speed Country                 Date
# City_ID
# 0              40%        0.00      RU  2023-04-22 12:24:48
# 1             100%       16.88      TF  2023-04-22 12:25:22
# 2              75%        8.75      AR  2023-04-22 12:21:25
# 3              93%        0.89      NZ  2023-04-22 12:25:22
# 4              95%        4.21      PW  2023-04-22 12:33:12

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
